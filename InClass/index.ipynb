# %% [markdown]
# ## Welcome/Intro to this dict
# Hello! I'm so glad that you decided to download this notebook. This notebook contains a dictionary of each and every concept we've learned in Data Science For Biologists, and where to go to learn more about it
# ## How it works
# If you'd like to find a specific concept:
# - Review the different keys (stored in a **concepts** list) to see if/how that concept is presented in the dictionary
# - Type the key value into the input cell
# - What is returned will be either a **slide number** (with a Slide: in the value) or a **search term**
# - Use the provided **slide number** or **search term** and either:
#     1. Locate the appropriate presentation/slide (if a **slide number**)
#     2. Search the term using Ctrl+F or Cmd+F in the notebook (if a **search term**)

# %%
from pprint import pprint
class_index = {
    'Observations/Features':'01_Sept6_data, Slides 5-9',
    'pwd':'02_Sept7_os, Slide 15',
    'mkdir':'02_Sept7_os, Slide 21',
    'ls':'02_Sept7_os, Slide 23',
    'cd':'02_Sept7_os, Slides 25-26',
    'cp':'02_Sept7_os, Slide 31',
    'mv':'02_Sept7_os, Slide 31',
    'rm':'02_Sept7_os, Slide 32',
    'rmdir':'02_Sept7_os, Slide 33',
    'man':'02_Sept7_os, Slide 35',
    'tar':'02_Sept7_os, Slide 36',
    'Wildcards':'02_Sept7_os, Slide 38',
    'gunzip':'02_Sept7_os, Slide 39',
    'Tab completion':'02_Sept7_os, Slide 40',
    'less':'02_Sept7_os, Slide 41',
    'head/tail':'02_Sept7_os, Slide 42',
    'grep':'03_Sep8_head_tail_pipes, Slides 11, 13',
    'Pipes':'03_Sep8_head_tail_pipes, Slide 12',
    'cut':'03_Sep8_head_tail_pipes, Slide 17',
    'sort':'03_Sep8_head_tail_pipes, Slides 19-21',
    'uniq':'03_Sep8_head_tail_pipes, Slide 22',
    'Basic Python Operations':'04_variables_assignment_copy, Slide 26',
    'print()':'06_Sept15_intro, Program 1',
    '<, >, and/or':'06_Sept15_intro, Program 2',
    'Lists':'06_Sept15_intro, Lists',
    'Indexing':'06_Sept15_intro, Exercise 4',
    'len()':'06_Sept15_intro, Exercise 5',
    'Code Comments':'07_Sept20_datastructures, Comments',
    'if/else':'07_Sept20_datastructures, 0. if/else review',
    'string.split()':'07_Sept20_datastructures, String objects and practicing with lists',
    'Sets':'07_Sept20_datastructures, Sets',
    'Dictionaries':'07_Sept20_datastructures, Dictionaries',
    'Loops':'07_Sept20_datastructures, 2. Loops',
    'range()':'07_Sept20_datastructures, use the function range',
    'Looping through lines in a file':'07_Sept20_datastructures, 2.3 Looping through lines in a file',
    'Algorithmic Thinking':'09_Sept22_algorithmic_fancydict, Algorithmic thinking',
    'Pandas/pd':'09_Sept22_algorithmic_fancydict, 2.1 Making a DataFrame',
    'DataFrames':'09_Sept22_algorithmic_fancydict, 2.1 Making a DataFrame',
    'Importing packages':'09_Sept22_algorithmic_fancydict, 2.1 Making a DataFrame',
    '.set_index()':'09_Sept22_algorithmic_fancydict, 2.2 Index and columns',
    '.loc[]':'09_Sept22_algorithmic_fancydict, 2.3 .loc[] through 2.5 Indexing using a list',
    '.iloc[]':'09_Sept22_algorithmic_fancydict, 2.6 .iloc[]',
    'Working with Series':'09_Sept22_algorithmic_fancydict, 3. Vectorized operations',
    'Vectorized Boolean Operations':'09_Sept22_algorithmic_fancydict, 3.5 Vectorized Boolean operations',
    '.shape':'09_Sept22_algorithmic_fancydict, 4. Dimension/shape',
    'Adding to a DataFrame':'10_Sept28_dataframe_slicing, 5. Assigning into your data frame',
    'Boolean Indexing':'10_Sept28_dataframe_slicing, 6. Boolean indexing',
    '.sort_values()':'10_Sept28_dataframe_slicing, 7. Sorting',
    'Reading Data from a File':'10_Sept28_dataframe_slicing, 8. Reading in data',
    '.head()/.tail()':'10_Sept28_dataframe_slicing, 8.1 Exploring the data',
    '.describe()':'10_Sept28_dataframe_slicing, 9. Univariate summaries',
    '.max()':'10_Sept28_dataframe_slicing, 9. Univariate summaries',
    '.min()':'10_Sept28_dataframe_slicing, 9. Univariate summaries',
    'NumPy/np':'10_Sept28_dataframe_slicing, Exercise 9.1',
    'np.linspace()':'10_Sept28_dataframe_slicing, Exercise 9.1',
    'Seaborn/sns':'11_Oct4_dataframe_slicing, 10. Intro to Plotting',
    '.barplot()':'11_Oct4_dataframe_slicing, 10.2 Bar plot',
    '.displot()':'11_Oct4_dataframe_slicing, 10.2 Histogram',
    'pd.concat()':'12_Oct11_whole_df_operations, 1.1 Concatenate DataFrames',
    '.transpose()':'12_Oct11_whole_df_operations, 1.2 transpose()',
    '.sum()':'12_Oct11_whole_df_operations, 4. Vectorized operations across multiple rows/columns',
    '.mean()':'12_Oct11_whole_df_operations, 4. Vectorized operations across multiple rows/columns',
    '.relplot()':'12_Oct11_whole_df_operations, 5. Plots of two or more features',
    'Seaborn/sns - col=':'12_Oct11_whole_df_operations, 5.1 Bivariate plots',
    'Seaborn/sns - stat=':'12_Oct11_whole_df_operations, Exercise 5.1.1',
    'Seaborn/sns - common_norm=':'12_Oct11_whole_df_operations, Exercise 5.1.2',
    'Seaborn/sns - hue=':'12_Oct11_whole_df_operations, Exercise 5.1.3',
    'Seaborn/sns - kde=':'12_Oct11_whole_df_operations, Exercise 5.1.3',
    '.str.startswith()':'12_Oct11_whole_df_operations, vectorized string operations',
    '.str.endswith()':'12_Oct11_whole_df_operations, vectorized string operations',
    '.str.contains()':'12_Oct11_whole_df_operations, vectorized string operations',
    '.groupby()':'13_Oct19_variables_visualization, 0. Grouping your data',
    '.catplot()':'13_Oct19_variables_visualization, 1. \"categorical plots\"',
    'Box Plots':'13_Oct19_variables_visualization, 1. \"categorical plots\", 1.2 Box Plots',
    'Violin Plots':'13_Oct19_variables_visualization, Exercise 1.3',
    'Strip Plots':'13_Oct19_variables_visualization, 1. \"categorical plots\"',
    'Seaborn/sns - bins=':'14_Oct25_variables_models, Exercise 3.1',
    '.size()':'13_Oct19_variables_visualization, 0. Grouping your data',
    'bernoulli.rvs()':'14_Oct25_variables_models, 5.1 Model binary data',
    'norm.rvs()':'15_Oct26_models_parameters, 3. Normal (Gaussian) Model',
    'bernoulli.pmf()':'16_Oct27_likelihood_normal, 1. Probabilities in Bernoulli, pmf',
    'Likelihood':'16_Oct27_likelihood_normal, 1.1 From probabilitiy to likelihood',
    'np.log':'16_Oct27_likelihood_normal, Exercise 1.1.1',
    'norm.pdf()':'17_Nov1_likelihood_normal, Exercise 2.2',
    'norm - scale=':'17_Nov1_likelihood_normal, 2.1 scale',
    'pd.isnull()':'17_Nov1_likelihood_normal, 2.2 Maximum likelihood normal model',
    'matplotlib.pyplot':'12_Oct11_whole_df_operations, Extra.2 Matplotlib',
    'StatsModels/sm':'17_Nov1_likelihood_normal, 4. Using statsmodels',
    'sm.add_constant':'17_Nov1_likelihood_normal, use the `add_constant`',
    '.drop()':'17_Nov1_likelihood_normal, 4.2 Convert to input for Statsmodels',
    'sm.OLS()':'17_Nov1_likelihood_normal, Now, we can use statsmodels to',
    'model.fit()':'17_Nov1_likelihood_normal, Now, we can use statsmodels to',
    'model.summary()':'17_Nov1_likelihood_normal, The `summary()` function',
    'model.params':'17_Nov1_likelihood_normal, 4.1 Understanding the model parameters',
    'model.predict()':'18_Nov8_linear_regression, Exercise 4.1.2',
    '.corr()':'18_Nov8_linear_regression, using `corr`',
    'Residuals':'18_Nov8_linear_regression, 5.1 Residuals',
    'RMSE':'18_Nov8_linear_regression, 5.2 RMSE',
    'Multiple Predictors':'20_Nov29_linear_metrics_2predictors',
    'pd.crosstab()':'6.1 Collinearity of two independent variables'
}

concepts = list(class_index.keys())
concepts.sort()
concepts
# Out:
# ['.barplot()',
#  '.catplot()',
#  '.corr()',
#  '.describe()',
#  '.displot()',
#  '.drop()',
#  '.groupby()',
#  '.head()/.tail()',
#  '.iloc[]',
#  '.loc[]',
#  '.max()',
#  '.mean()',
#  '.min()',
#  '.relplot()',
#  '.set_index()',
#  '.shape',
#  '.size()',
#  '.sort_values()',
#  '.str.contains()',
#  '.str.endswith()',
#  '.str.startswith()',
#  '.sum()',
#  '.transpose()',
#  '<, >, and/or',
#  'Adding to a DataFrame',
#  'Algorithmic Thinking',
#  'Basic Python Operations',
#  'Boolean Indexing',
#  'Box Plots',
#  'Code Comments',
#  'DataFrames',
#  'Dictionaries',
#  'Importing packages',
#  'Indexing',
#  'Likelihood',
#  'Lists',
#  'Looping through lines in a file',
#  'Loops',
#  'Multiple Predictors',
#  'NumPy/np',
#  'Observations/Features',
#  'Pandas/pd',
#  'Pipes',
#  'RMSE',
#  'Reading Data from a File',
#  'Residuals',
#  'Seaborn/sns',
#  'Seaborn/sns - bins=',
#  'Seaborn/sns - col=',
#  'Seaborn/sns - common_norm=',
#  'Seaborn/sns - hue=',
# ...

# %%
# Example with norm.rvs() provided
class_index['norm.rvs()']
# Out:
# '15_Oct26_models_parameters, 3. Normal (Gaussian) Model'
