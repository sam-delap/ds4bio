# %% [markdown]
# #### Use the ecosites data. Make a visualization that will allow you to visualize if sites in the "E" region are at a different latitude than sites in the"W" region. Compare your results to [figure 2](https://www.nature.com/articles/s41467-019-10253-6/figures/2) from the paper (don't worry about all the parts about the motifs, just look at the maps)
# #### How do the results compare?
# Our results are similar to those in the paper. Figure 2 demonstrates that the latitude measurements are in `°E`, so it makes sense that sites classified as `E` in the dataset have higher latitude numbers (between 88 and 93) than those classified as `W` (between 75 and 80)

# %%
# Import packages and load data
import pandas as pd
import seaborn as sns
sns.set_theme()
sites = pd.read_table("../Data/eco_data/eco_sites.txt")

# Isolate only the data we're interested in (East (latitude) and WorE)
latitude = sites.loc[:,['East', 'WorE']]

# Plot the latitude of locations in the east and locations in the west
sns.displot(data = latitude, x = 'East', col = 'WorE')
